# %%
import polars as pl

# %%
df = pl.read_parquet('test_data/cells/AR3753/processed/AR3753_AR-3753_3_electrode_full_GITT_EIS_0_04_MB_C06_20250911_084925.parquet')

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# ['time_s',
#  'working_electrode_potential_v',
#  'ce_potential_v',
#  'impedance_mag_ohm',
#  'impedance_phase_deg',
#  'frequency_hz',
#  'we_impedance_real_ohm',
#  'we_impedance_imag_ohm',
#  'we_impedance_mag_ohm',
#  'ce_impedance_real_ohm',
#  'ce_impedance_imag_ohm',
#  'ce_impedance_mag_ohm',
#  'ce_impedance_phase_deg',
#  'current_a',
#  'potential_v',
#  'current_avg_a',
#  'aux_voltage_v',
#  'point_number',
#  'timestamp',
#  'energy_cumulative_wh',
#  'current_range',
#  'capacity_ah',
#  'segment_number',
#  'capacity_absolute_cumulative_ah',
#  'battery_cycle',
#  'energy_wh',
#  'energy_absolute_cumulative_wh',
#  'impedance_real_ohm',
#  'potential_avg_v',
#  'energy_charge_cumulative_wh',
#  'capacity_cumulative_ah',
#  'potential_range',
#  'cell_potential_v',
#  'status_flags',
#  'charge_cumulative_ah',
#  'current_applied_a',
#  'temperature_c',
#  'energy_discharge_cumulative_wh',
#  'impedance_imag_ohm',
#  'loop_number',
#  'potential_applied_v',
# ...

# %%
df['segment_number']
# Out:
# shape: (136_139,)
# Series: 'segment_number' [i32]
# [
# 	null
# 	1
# 	1
# 	1
# 	1
# 	…
# 	1
# 	1
# 	1
# 	1
# 	1
# ]

# %%
plt.plot(df['time_s'], df['technique_id'])
